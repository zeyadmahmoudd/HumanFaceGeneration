# %%
# !pip install datasets
# !pip install diffusers
# !pip install accelerate
# !pip install --upgrade torchmetrics[image]
# !pip install --upgrade torch-fidelity
# Out:
# Requirement already satisfied: datasets in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (2.18.0)
# Requirement already satisfied: filelock in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (1.26.3)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (0.21.4)
# Requirement already satisfied: packaging in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests>=2.19.0->datasets) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: diffusers in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (0.27.2)
# Requirement already satisfied: importlib-metadata in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from diffusers) (7.0.2)
# Requirement already satisfied: filelock in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from diffusers) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from diffusers) (0.21.4)
# Requirement already satisfied: numpy in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from diffusers) (1.26.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from diffusers) (2023.12.25)
# Requirement already satisfied: requests in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from diffusers) (0.4.2)
# Requirement already satisfied: Pillow in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from diffusers) (10.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers) (2023.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub>=0.20.2->diffusers) (23.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from importlib-metadata->diffusers) (3.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests->diffusers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests->diffusers) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.20.2->diffusers) (0.4.6)
# Requirement already satisfied: accelerate in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (0.30.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from accelerate) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from accelerate) (2.2.1)
# Requirement already satisfied: huggingface-hub in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from accelerate) (0.21.4)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->accelerate) (4.9.0)
# Requirement already satisfied: sympy in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->accelerate) (2023.10.0)
# Requirement already satisfied: requests in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub->accelerate) (4.65.0)
# Requirement already satisfied: colorama in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests->huggingface-hub->accelerate) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: torchmetrics[image] in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy>1.20.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchmetrics[image]) (1.26.3)
# Requirement already satisfied: packaging>17.1 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchmetrics[image]) (23.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchmetrics[image]) (2.2.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchmetrics[image]) (0.9.0)
# Requirement already satisfied: pretty-errors==1.2.25 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchmetrics[image]) (1.2.25)
# Requirement already satisfied: torch-fidelity<=0.4.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchmetrics[image]) (0.3.0)
# Requirement already satisfied: torchvision>=0.8 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchmetrics[image]) (0.17.1)
# Requirement already satisfied: scipy>1.0.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchmetrics[image]) (1.13.0)
# Requirement already satisfied: colorama in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from pretty-errors==1.2.25->torchmetrics[image]) (0.4.6)
# Requirement already satisfied: typing-extensions in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics[image]) (4.9.0)
# Requirement already satisfied: filelock in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->torchmetrics[image]) (3.13.1)
# Requirement already satisfied: sympy in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->torchmetrics[image]) (1.12)
# Requirement already satisfied: networkx in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->torchmetrics[image]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->torchmetrics[image]) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch>=1.10.0->torchmetrics[image]) (2023.10.0)
# Requirement already satisfied: Pillow in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch-fidelity<=0.4.0->torchmetrics[image]) (10.2.0)
# Requirement already satisfied: tqdm in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch-fidelity<=0.4.0->torchmetrics[image]) (4.65.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from jinja2->torch>=1.10.0->torchmetrics[image]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from sympy->torch>=1.10.0->torchmetrics[image]) (1.3.0)
# Requirement already satisfied: torch-fidelity in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (0.3.0)
# Requirement already satisfied: numpy in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch-fidelity) (1.26.3)
# Requirement already satisfied: Pillow in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch-fidelity) (10.2.0)
# Requirement already satisfied: scipy in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch-fidelity) (1.13.0)
# Requirement already satisfied: torch in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch-fidelity) (2.2.1)
# Requirement already satisfied: torchvision in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch-fidelity) (0.17.1)
# Requirement already satisfied: tqdm in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch-fidelity) (4.65.0)
# Requirement already satisfied: filelock in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch->torch-fidelity) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch->torch-fidelity) (4.9.0)
# Requirement already satisfied: sympy in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch->torch-fidelity) (1.12)
# Requirement already satisfied: networkx in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch->torch-fidelity) (3.1)
# Requirement already satisfied: jinja2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch->torch-fidelity) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch->torch-fidelity) (2023.10.0)
# Requirement already satisfied: colorama in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from tqdm->torch-fidelity) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from jinja2->torch->torch-fidelity) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from sympy->torch->torch-fidelity) (1.3.0)

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cuXXX
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cuXXX
# Requirement already satisfied: torch in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (2.2.1)
# Requirement already satisfied: torchvision in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (0.17.1)
# Requirement already satisfied: torchaudio in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (2.2.1)
# Requirement already satisfied: filelock in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: numpy in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchvision) (1.26.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sigma\anaconda3\envs\myenv\lib\site-packages (from sympy->torch) (1.3.0)

# %%
import torch
import torchvision
import math
import os

from torchvision import transforms
from datasets import load_dataset
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

import torch.nn.functional as F
from diffusers import DDPMScheduler
from diffusers import UNet2DModel
from diffusers import DDPMPipeline
from diffusers.optimization import get_cosine_schedule_with_warmup
from datasets import load_dataset
from dataclasses import dataclass
from PIL import Image

from accelerate import Accelerator
from tqdm.auto import tqdm
from pathlib import Path
import os

from accelerate import notebook_launcher

import glob

import os

from PIL import Image
import numpy as np

from diffusers import DDPMPipeline

import torch
from PIL import Image

from torchmetrics.image.fid import FrechetInceptionDistance

from shutil import copyfile

import matplotlib.pyplot as plt

from diffusers import DiTPipeline, DPMSolverMultistepScheduler

from torchvision.transforms import functional as F

# %%
#class for adjusting training hyperparameters

@dataclass
class TrainingConfig:
    image_size = 64  # the generated image resolution, not sure what image size to use.
    train_batch_size = 16
    eval_batch_size = 16  # how many images to sample during evaluation
    num_epochs = 500                                              
    gradient_accumulation_steps = 1
    learning_rate = 1e-4
    lr_warmup_steps = 500
    save_image_epochs = 10
    save_model_epochs = 20
    mixed_precision = "fp16"  # `no` for float32, `fp16` for automatic mixed precision
    output_dir = "C:/Users/sigma/Downloads/AML_course_work/loss_function"  # directory to save the output localy

    overwrite_output_dir = True  # overwrite the old model when re-running the notebook
    seed = 42
    losses = []

config = TrainingConfig()

# %%
# Path to your dataset directory
dataset_dir = "C:/Users/sigma/Downloads/celeba_hq_256"

full_train_dataset = load_dataset(dataset_dir, split="train")

# Path to where you want to save the train and test datasets
train_dir = "C:/Users/sigma/Downloads/AML_course_work/data/train"
test_dir = "C:/Users/sigma/Downloads/AML_course_work/data/test"

# Create train and test directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split the dataset into train and test sets
split_ratio = 0.95
split = full_train_dataset.train_test_split(test_size=1 - split_ratio)

dataset_train = split['train']
dataset_test = split['test']

#save the training images
i = 0
for im in dataset_train["image"]:
  im.save(os.path.join(train_dir,"image"+str(i)+".png"))
  i = i + 1

#save the testing images
i = 0
for im in dataset_test["image"]:
  im.save(os.path.join(test_dir,"image"+str(i)+".png"))
  i = i + 1
# Out:
# Resolving data files:   0%|          | 0/2666 [00:00<?, ?it/s]

# %%
#loading train dataset
dataset = load_dataset(train_dir)
# Out:
# Resolving data files:   0%|          | 0/2531 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# train_dataset
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 2531
#     })
# })

# %%
#visualzing first 4 images in train dataset

fig, axs = plt.subplots(1, 4, figsize=(16, 4))
for i, image in enumerate(dataset['train'][:4]["image"]):
    axs[i].imshow(image)
    axs[i].set_axis_off()
plt.show()

print(len(dataset['train']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       3 fig, axs = plt.subplots(1, 4, figsize=(16, 4))
# ----> 4 for i, image in enumerate(dataset['train'][:4]["image"]):
#       5     axs[i].imshow(image)
#       6     axs[i].set_axis_off()
#
# NameError: name 'dataset' is not defined

# %%
#building transforms to be used on datset

preprocess=transforms.Compose([
        transforms.Resize((config.image_size, config.image_size)),  # Resize
        transforms.RandomHorizontalFlip(),  # Randomly flip (data augmentation)
        transforms.ToTensor(),  # Convert to tensor (0, 1)
        transforms.Normalize([0.5], [0.5]),  # Map to (-1, 1) # Note that the model expexts this distribution
    ])

# %%
def transform(examples):
    images = [preprocess(image.convert("RGB")) for image in examples["image"]]
    return {"images": images}

dataset.set_transform(transform) # This will apply the preprocess function of the fly during the training

train_dataloader = torch.utils.data.DataLoader(
    dataset['train'], batch_size=config.train_batch_size, shuffle=True
)

# %%
#printing first batch

for batch in train_dataloader:
    print(batch)
    break  # Print only the first batch for brevity
# Out:
# {'images': tensor([[[[ 0.3020,  0.3020,  0.2941,  ...,  0.3882,  0.3882,  0.3882],
#           [ 0.3020,  0.3020,  0.2941,  ...,  0.3882,  0.3882,  0.3882],
#           [ 0.3098,  0.2941,  0.2941,  ...,  0.3804,  0.3882,  0.3882],
#           ...,
#           [ 0.2941,  0.2941,  0.3020,  ..., -0.0431,  0.2078,  0.2863],
#           [ 0.2941,  0.2941,  0.3020,  ..., -0.0353, -0.0667,  0.1608],
#           [ 0.2941,  0.2941,  0.3020,  ...,  0.0745, -0.0588, -0.1373]],
#
#          [[ 0.3098,  0.3098,  0.2941,  ...,  0.3882,  0.3882,  0.3882],
#           [ 0.3098,  0.3098,  0.2941,  ...,  0.3882,  0.3882,  0.3882],
#           [ 0.3176,  0.3020,  0.2941,  ...,  0.3804,  0.3882,  0.3882],
#           ...,
#           [ 0.2941,  0.2941,  0.3020,  ..., -0.2157,  0.1765,  0.3490],
#           [ 0.2941,  0.2941,  0.3020,  ..., -0.3647, -0.2471,  0.1137],
#           [ 0.2941,  0.2941,  0.3020,  ..., -0.3255, -0.3804, -0.3490]],
#
#          [[ 0.3412,  0.3490,  0.3569,  ...,  0.4667,  0.4667,  0.4667],
#           [ 0.3412,  0.3490,  0.3569,  ...,  0.4667,  0.4667,  0.4667],
#           [ 0.3490,  0.3412,  0.3569,  ...,  0.4588,  0.4667,  0.4667],
#           ...,
#           [ 0.3725,  0.3725,  0.3804,  ..., -0.3176,  0.1765,  0.4039],
#           [ 0.3725,  0.3725,  0.3804,  ..., -0.5608, -0.3412,  0.0980],
#           [ 0.3725,  0.3725,  0.3804,  ..., -0.5608, -0.5686, -0.4824]]],
#
#
#         [[[ 0.8510,  0.8510,  0.8431,  ...,  0.7255,  0.7255,  0.7255],
#           [ 0.8510,  0.8510,  0.8431,  ...,  0.7412,  0.7255,  0.7255],
#           [ 0.8510,  0.8510,  0.8510,  ...,  0.7333,  0.7255,  0.7255],
#           ...,
#           [ 0.8353,  0.8353,  0.8353,  ...,  0.6627,  0.6627,  0.6314],
#           [ 0.8353,  0.8353,  0.8353,  ...,  0.6706,  0.7020,  0.6627],
#           [ 0.8353,  0.8353,  0.8353,  ...,  0.6627,  0.6941,  0.7020]],
#
#          [[ 0.8824,  0.8824,  0.8745,  ...,  0.7569,  0.7569,  0.7569],
#           [ 0.8824,  0.8824,  0.8745,  ...,  0.7725,  0.7569,  0.7569],
#           [ 0.8824,  0.8824,  0.8824,  ...,  0.7647,  0.7569,  0.7569],
#           ...,
#           [ 0.8667,  0.8667,  0.8667,  ...,  0.6784,  0.7020,  0.6784],
#           [ 0.8667,  0.8667,  0.8667,  ...,  0.6863,  0.7333,  0.7176],
#           [ 0.8667,  0.8667,  0.8667,  ...,  0.6784,  0.7333,  0.7490]],
#
#          [[ 0.9686,  0.9686,  0.9608,  ...,  0.8431,  0.8431,  0.8431],
#           [ 0.9686,  0.9686,  0.9608,  ...,  0.8588,  0.8431,  0.8431],
#           [ 0.9686,  0.9686,  0.9686,  ...,  0.8510,  0.8431,  0.8431],
#           ...,
#           [ 0.9529,  0.9529,  0.9529,  ...,  0.7176,  0.7490,  0.7412],
#           [ 0.9529,  0.9529,  0.9529,  ...,  0.7255,  0.7882,  0.7725],
#           [ 0.9529,  0.9529,  0.9529,  ...,  0.7176,  0.7804,  0.8118]]],
#
#
#         [[[-0.4353, -0.4353, -0.4431,  ...,  0.3647,  0.3725,  0.3725],
#           [-0.4824, -0.4824, -0.4980,  ...,  0.3804,  0.3882,  0.3882],
#           [-0.5451, -0.5451, -0.5529,  ...,  0.3882,  0.4039,  0.3961],
#           ...,
#           [-0.9059, -0.8745, -0.8275,  ...,  0.4039,  0.3569,  0.3098],
#           [-0.6392, -0.5529, -0.3961,  ...,  0.5451,  0.5294,  0.4902],
#           [-0.2784, -0.1922,  0.0431,  ...,  0.6471,  0.6471,  0.5922]],
#
#          [[-0.7176, -0.7176, -0.7255,  ...,  0.1294,  0.1373,  0.1373],
#           [-0.7412, -0.7412, -0.7490,  ...,  0.1686,  0.1843,  0.1843],
#           [-0.7647, -0.7647, -0.7725,  ...,  0.2157,  0.2314,  0.2235],
#           ...,
#           [-0.9373, -0.9451, -0.9451,  ..., -0.4510, -0.4667, -0.4588],
#           [-0.8431, -0.8196, -0.7569,  ..., -0.3647, -0.3725, -0.3725],
#           [-0.7569, -0.7176, -0.5608,  ..., -0.2549, -0.2706, -0.2941]],
#
#          [[-0.7882, -0.7882, -0.7961,  ..., -0.2157, -0.2078, -0.2078],
#           [-0.8039, -0.8039, -0.8118,  ..., -0.1765, -0.1608, -0.1608],
#           [-0.8275, -0.8275, -0.8275,  ..., -0.1216, -0.1059, -0.1137],
#           ...,
#           [-0.9137, -0.9216, -0.9137,  ..., -0.7333, -0.7412, -0.7412],
#           [-0.8745, -0.8667, -0.8353,  ..., -0.7020, -0.6941, -0.6941],
#           [-0.8431, -0.8510, -0.7569,  ..., -0.6471, -0.6392, -0.6627]]],
#
#
#         ...,
#
#
#         [[[-0.4275, -0.4431, -0.4745,  ..., -0.0196, -0.1294, -0.2706],
#           [-0.4431, -0.4588, -0.4824,  ..., -0.3961, -0.4353, -0.4510],
#           [-0.4667, -0.4745, -0.4824,  ..., -0.4667, -0.4275, -0.4353],
#           ...,
#           [-0.8980, -0.9059, -0.8980,  ..., -0.3804, -0.4275, -0.4824],
#           [-0.8745, -0.8902, -0.8902,  ..., -0.3961, -0.4431, -0.5059],
#           [-0.8431, -0.8667, -0.8667,  ..., -0.4118, -0.4588, -0.5373]],
#
#          [[-0.5294, -0.5451, -0.5765,  ..., -0.0510, -0.1608, -0.3255],
#           [-0.5451, -0.5608, -0.5843,  ..., -0.4196, -0.4745, -0.5059],
#           [-0.5686, -0.5765, -0.5843,  ..., -0.4902, -0.4588, -0.4902],
#           ...,
#           [-0.9294, -0.9373, -0.9294,  ..., -0.3412, -0.4275, -0.4980],
#           [-0.9059, -0.9216, -0.9216,  ..., -0.3569, -0.4431, -0.5216],
#           [-0.8745, -0.8980, -0.8980,  ..., -0.3725, -0.4588, -0.5608]],
#
#          [[-0.5922, -0.6078, -0.6392,  ..., -0.0745, -0.1843, -0.3412],
#           [-0.6078, -0.6235, -0.6471,  ..., -0.4431, -0.4980, -0.5216],
#           [-0.6314, -0.6392, -0.6471,  ..., -0.5216, -0.4824, -0.5059],
#           ...,
#           [-0.9373, -0.9451, -0.9373,  ..., -0.2314, -0.3412, -0.4275],
#           [-0.9137, -0.9294, -0.9294,  ..., -0.2471, -0.3569, -0.4510],
#           [-0.8824, -0.9059, -0.9059,  ..., -0.2627, -0.3725, -0.4824]]],
#
#
#         [[[ 1.0000,  1.0000,  1.0000,  ...,  0.9294,  0.9216,  0.9059],
#           [ 1.0000,  1.0000,  1.0000,  ...,  0.9294,  0.9216,  0.9059],
#           [ 1.0000,  1.0000,  1.0000,  ...,  0.9294,  0.9216,  0.9059],
#           ...,
#           [-0.8039, -0.8118, -0.8196,  ...,  0.9608,  0.9608,  0.9373],
#           [-0.8196, -0.8118, -0.8196,  ...,  0.9686,  0.9529,  0.9059],
#           [-0.8275, -0.8196, -0.8196,  ...,  0.9608,  0.9294,  0.8588]],
#
#          [[ 1.0000,  1.0000,  1.0000,  ...,  0.8588,  0.8118,  0.7804],
#           [ 1.0000,  1.0000,  1.0000,  ...,  0.8588,  0.8118,  0.7804],
#           [ 1.0000,  1.0000,  1.0000,  ...,  0.8588,  0.8196,  0.7804],
#           ...,
#           [-0.8824, -0.8902, -0.8980,  ...,  0.9451,  0.9059,  0.8588],
#           [-0.8980, -0.8902, -0.8980,  ...,  0.9529,  0.8980,  0.8275],
#           [-0.9059, -0.8980, -0.8980,  ...,  0.9451,  0.8745,  0.7804]],
#
#          [[ 1.0000,  1.0000,  1.0000,  ...,  0.8353,  0.7882,  0.7490],
#           [ 1.0000,  1.0000,  1.0000,  ...,  0.8353,  0.7882,  0.7490],
#           [ 1.0000,  1.0000,  1.0000,  ...,  0.8431,  0.7882,  0.7490],
#           ...,
#           [-0.8745, -0.8824, -0.8902,  ...,  0.9451,  0.8902,  0.8431],
#           [-0.8902, -0.8824, -0.8902,  ...,  0.9451,  0.8824,  0.8196],
#           [-0.8980, -0.8902, -0.8902,  ...,  0.9451,  0.8667,  0.7647]]],
#
#
#         [[[ 0.9451,  0.9451,  0.9451,  ...,  0.8353,  0.8275,  0.8118],
#           [ 0.9451,  0.9451,  0.9451,  ...,  0.8431,  0.8431,  0.8353],
#           [ 0.9451,  0.9451,  0.9451,  ...,  0.8431,  0.8431,  0.8431],
#           ...,
#           [ 0.0431,  0.1294,  0.1137,  ...,  0.7647,  0.7725,  0.7804],
#           [ 0.1608,  0.0902,  0.0353,  ...,  0.7647,  0.7804,  0.7882],
#           [ 0.1216,  0.0353,  0.0196,  ...,  0.7647,  0.7647,  0.7725]],
#
#          [[ 0.9373,  0.9373,  0.9373,  ...,  0.7490,  0.7412,  0.7255],
#           [ 0.9373,  0.9373,  0.9373,  ...,  0.7569,  0.7569,  0.7490],
#           [ 0.9373,  0.9373,  0.9373,  ...,  0.7569,  0.7569,  0.7569],
#           ...,
#           [ 0.0353, -0.0588, -0.1843,  ...,  0.7412,  0.7333,  0.7255],
#           [ 0.0431, -0.1451, -0.2392,  ...,  0.7412,  0.7412,  0.7333],
#           [-0.0824, -0.2314, -0.2549,  ...,  0.7412,  0.7255,  0.7176]],
#
#          [[ 0.9216,  0.9216,  0.9216,  ...,  0.7333,  0.7255,  0.7098],
#           [ 0.9216,  0.9216,  0.9216,  ...,  0.7412,  0.7412,  0.7333],
#           [ 0.9216,  0.9216,  0.9216,  ...,  0.7412,  0.7412,  0.7412],
#           ...,
#           [-0.0353, -0.3255, -0.5451,  ...,  0.7098,  0.7098,  0.7098],
#           [-0.1686, -0.4745, -0.6000,  ...,  0.7176,  0.7176,  0.7176],
#           [-0.3098, -0.5451, -0.5843,  ...,  0.7176,  0.7020,  0.7020]]]])}

# %%
# the model from hugging face
model = UNet2DModel(
    sample_size=config.image_size,  # the target image resolution
    in_channels=3,  # the number of input channels, 3 for RGB images
    out_channels=3,  # the number of output channels
    layers_per_block=2,  # how many ResNet layers to use per UNet block
    block_out_channels=(64, 128, 256, 256, 512, 512),  # the number of output channels for each UNet block
    down_block_types=(
        "DownBlock2D",  # a regular ResNet downsampling block
        "DownBlock2D",
        "DownBlock2D",
        "DownBlock2D",
        "AttnDownBlock2D",  # a ResNet downsampling block with spatial self-attention
        "DownBlock2D",
    ),
    up_block_types=(
        "UpBlock2D",  # a regular ResNet upsampling block
        "AttnUpBlock2D",  # a ResNet upsampling block with spatial self-attention
        "UpBlock2D",
        "UpBlock2D",
        "UpBlock2D",
        "UpBlock2D",
    ),
)

# %%
#Printing input shape

sample_image = dataset['train'][0]["images"].unsqueeze(0)
print("Input shape:", sample_image.shape) #To make sure that the sample image shape matches the modal output shape
# Out:
# Input shape: torch.Size([1, 3, 64, 64])

# %%
#Printing output shape

print("Output shape:", model(sample_image, timestep=0).sample.shape)
# Out:
# Output shape: torch.Size([1, 3, 64, 64])

# %%
# During training, the schedular takes a model's output and applies noise to the image
# During inference, the scheduler generates image from the noise

noise_scheduler = DDPMScheduler(num_train_timesteps=1000)
noise = torch.randn(sample_image.shape)
timesteps = torch.LongTensor([50])
noisy_image = noise_scheduler.add_noise(sample_image, noise, timesteps)

Image.fromarray(((noisy_image.permute(0, 2, 3, 1) + 1.0) * 127.5).type(torch.uint8).numpy()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64>

# %%
# The objective of the model is to predict the noise added to the image.

noise_pred = model(noisy_image, timesteps).sample

#Defining loss function

loss = F.l1_loss(noise_pred, noise)

# %%
#Defining optimizer and noise scheduler

optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate)
lr_scheduler = get_cosine_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=config.lr_warmup_steps,
    num_training_steps=(len(train_dataloader) * config.num_epochs),
)

# %%
#making grid to visualize output images from the model

def make_grid(images, rows, cols):
    w, h = images[0].size
    grid = Image.new("RGB", size=(cols * w, rows * h))
    for i, image in enumerate(images):
        grid.paste(image, box=(i % cols * w, i // cols * h))
    return grid

#model evaluation

def evaluate(config, epoch, pipeline):
    # Sample some images from random noise (this is the backward diffusion process)
    images = pipeline(
        batch_size=config.eval_batch_size,
        generator=torch.manual_seed(config.seed),
    ).images

    # Make a grid out of the images
    image_grid = make_grid(images, rows=4, cols=4)

    # Save the images
    test_dir = os.path.join(config.output_dir, "samples")
    os.makedirs(test_dir, exist_ok=True)
    image_grid.save(f"{test_dir}/{epoch:04d}.png")

# %%
#model training

def train_loop(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler):
    # Initialize accelerator and tensorboard logging
    accelerator = Accelerator(
        mixed_precision=config.mixed_precision,
        gradient_accumulation_steps=config.gradient_accumulation_steps,
        log_with="tensorboard",
        project_dir=os.path.join(config.output_dir, "logs"),
    )
    if accelerator.is_main_process:
        if config.output_dir is not None:
            os.makedirs(config.output_dir, exist_ok=True)
        accelerator.init_trackers("train_example")

 
    model, optimizer, train_dataloader, lr_scheduler = accelerator.prepare(
        model, optimizer, train_dataloader, lr_scheduler
    )

    global_step = 0


    for epoch in range(config.num_epochs):
        progress_bar = tqdm(total=len(train_dataloader), disable=not accelerator.is_local_main_process)
        progress_bar.set_description(f"Epoch {epoch}")

        for step, batch in enumerate(train_dataloader):
            clean_images = batch["images"]
            
            # Sample noise to add to the images
            
            noise = torch.randn(clean_images.shape).to(clean_images.device)
            bs = clean_images.shape[0]

            # Sample a random timestep for each image
            
            timesteps = torch.randint(
                0, noise_scheduler.config.num_train_timesteps, (bs,), device=clean_images.device
            ).long()

            # Add noise to the clean images according to the noise magnitude at each timestep
            noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

            with accelerator.accumulate(model):
                
                # Predict the noise residual
                
                noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
                loss = F.mse_loss(noise_pred, noise)
                config.losses.append(loss.item())#This is my addition
                accelerator.backward(loss)

                accelerator.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                lr_scheduler.step()
                optimizer.zero_grad()

            progress_bar.update(1)
            logs = {"loss": loss.detach().item(), "lr": lr_scheduler.get_last_lr()[0], "step": global_step}
            progress_bar.set_postfix(**logs)
            accelerator.log(logs, step=global_step)
            global_step += 1

        if accelerator.is_main_process:
            pipeline = DDPMPipeline(unet=accelerator.unwrap_model(model), scheduler=noise_scheduler)

            if (epoch + 1) % config.save_image_epochs == 0 or epoch == config.num_epochs - 1:
                evaluate(config, epoch, pipeline)

            if (epoch + 1) % config.save_model_epochs == 0 or epoch == config.num_epochs - 1:
              pipeline.save_pretrained(config.output_dir)

# %%
args = (config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler)

notebook_launcher(train_loop, args, num_processes=1)
# Out:
# Launching training on one GPU.
#   0%|          | 0/159 [00:00<?, ?it/s]
# C:\Users\sigma\anaconda3\envs\myenv\Lib\site-packages\diffusers\models\attention_processor.py:1279: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   hidden_states = F.scaled_dot_product_attention(
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]

# %%
# Display the sample images saved during the training

sample_images = sorted(glob.glob(f"{config.output_dir}/samples/*.png"))
Image.open(sample_images[-1])

# %%
plt.figure(figsize=(10,3))
plt.plot(config.losses)

# %%
#checking cuda is working

device="cuda" if torch.cuda.is_available() else "cpu"

#constructing pipeline from unet and noise scheduler

pipe= DDPMPipeline(unet=model,scheduler=noise_scheduler)
pipe.to(device)

# %%
pipe().images[0]

# %%
images = pipe(
        batch_size=3,
        generator=torch.manual_seed(config.seed),
    ).images
test_dir = os.path.join("generated_images", "samples")
os.makedirs(test_dir, exist_ok=True)
for i,image in enumerate(images):
    image.save(f"{test_dir}/{i:04d}.png")

# %%
dataset_path = "/content/test"
image_paths = sorted([os.path.join(dataset_path, x) for x in os.listdir(dataset_path)])

real_images = [np.array(Image.open(path).convert("RGB")) for path in image_paths]

# %%
def preprocess_image(image):
    image = torch.tensor(image).unsqueeze(0)
    image = image.permute(0, 3, 1, 2) / 255.0
    return F.center_crop(image, (256, 256))

real_images = torch.cat([preprocess_image(image) for image in real_images])
print(real_images.shape)

# %%
#generaing fake images with considerable amount compared to test images

fake_images = pipe(
        batch_size=134,
        generator=torch.manual_seed(config.seed),
    ).images

# %%
# Define transformations

transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize the image to a fixed size
    transforms.ToTensor(),           # Convert image to PyTorch tensor
])

# Apply transformations to each image in the list

fake_images_tensor = torch.stack([transform(img) for img in fake_images])

print(fake_images_tensor.shape)

# %%
fake_images = fake_images_tensor
print(fake_images.shape)

# %%
#Computing FID score wich is a measure of how well the generated images are compared to real images

fid = FrechetInceptionDistance(normalize=True)
fid.update(real_images, real=True)
fid.update(fake_images, real=False)

print(f"FID: {float(fid.compute())}")
